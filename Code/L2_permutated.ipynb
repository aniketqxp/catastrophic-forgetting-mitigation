# %% [markdown]
# # L2 Permutated

# %% [markdown]
# ## L2 Regularization
#
# **Key Idea**: Constrain parameters to stay close to their initial values from previous tasks.
#
# **Methodology**: Penalize parameter changes globally using a simple L2 norm loss penalty scaled by $\lambda$. Reduces forgetting but indiscriminately restricts both important and unimportant weights.

# %% [markdown]
# ### Setup and Data Loading

# %%
import sys
sys.path.insert(0, '..')

import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader

from src import (
    set_seed, PermutedMNIST, SimpleNN, store_initial_params,
    train_task_with_l2_regularization, evaluate_all_tasks,
    calculate_forgetting_metrics, plot_all_results
)

set_seed(42)

num_tasks = 5
input_size = 28 * 28
hidden_size = 256
output_size = 10
learning_rate = 0.01
epochs_per_task = 5
batch_size = 64
l2_lambda = 0.01  # L2 regularization strength

permutations = [torch.randperm(input_size) for _ in range(num_tasks)]

train_tasks = [PermutedMNIST(root="./data", train=True, permutations=permutations[i]) for i in range(num_tasks)]
test_tasks = [PermutedMNIST(root="./data", train=False, permutations=permutations[i]) for i in range(num_tasks)]

train_loaders = [DataLoader(train_tasks[i], batch_size=batch_size, shuffle=True) for i in range(num_tasks)]
test_loaders = [DataLoader(test_tasks[i], batch_size=batch_size, shuffle=False) for i in range(num_tasks)]

# %% [markdown]
# ### Sequential Training Loop with L2 Regularization

# %%
model = SimpleNN(input_size, hidden_size, output_size)
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=learning_rate)

training_losses = []
task_accuracies_history = []
initial_accuracies = []
initial_params_list = []

for task_idx in range(num_tasks):
    print(f"\n{'='*50}\nTraining on Task {task_idx+1}\n{'='*50}")
    
    task_loss, _ = train_task_with_l2_regularization(
        model, task_idx, train_loaders[task_idx], criterion, optimizer,
        initial_params_list if task_idx > 0 else None,
        l2_lambda=l2_lambda, epochs=epochs_per_task
    )
    training_losses.extend(task_loss)
    
    # Store parameters after training
    initial_params_list.append(store_initial_params(model))
    
    print("\nEvaluating on all tasks seen so far:")
    task_accs = evaluate_all_tasks(model, test_loaders[:task_idx+1])
    
    task_accuracies_history.append(task_accs)
    initial_accuracies.append(task_accs[0] if task_idx == 0 else task_accs[-1])
# Out:
# ==================================================
# Training on Task 1
# ==================================================
# Task 1, Epoch 1/5, Loss: 1.1872, Accuracy: 76.11%
# Task 1, Epoch 2/5, Loss: 0.4864, Accuracy: 87.64%
# Task 1, Epoch 3/5, Loss: 0.3910, Accuracy: 89.32%
# Task 1, Epoch 4/5, Loss: 0.3512, Accuracy: 90.11%
# Task 1, Epoch 5/5, Loss: 0.3269, Accuracy: 90.73%
#
# Evaluating on all tasks seen so far:
# Task 1 Accuracy: 91.57%
#
# ==================================================
# Training on Task 2
# ==================================================
# Task 2, Epoch 1/5, Loss: 0.7099, Accuracy: 82.30%
# Task 2, Epoch 2/5, Loss: 0.4475, Accuracy: 89.32%
# Task 2, Epoch 3/5, Loss: 0.4159, Accuracy: 90.35%
# Task 2, Epoch 4/5, Loss: 0.4012, Accuracy: 91.03%
# Task 2, Epoch 5/5, Loss: 0.3920, Accuracy: 91.41%
#
# Evaluating on all tasks seen so far:
# Task 1 Accuracy: 89.70%
# Task 2 Accuracy: 92.06%
#
# ==================================================
# Training on Task 3
# ==================================================
# Task 3, Epoch 1/5, Loss: 0.7435, Accuracy: 82.39%
# Task 3, Epoch 2/5, Loss: 0.5345, Accuracy: 89.39%
# Task 3, Epoch 3/5, Loss: 0.5108, Accuracy: 90.31%
# Task 3, Epoch 4/5, Loss: 0.4991, Accuracy: 90.86%
# Task 3, Epoch 5/5, Loss: 0.4922, Accuracy: 91.18%
#
# Evaluating on all tasks seen so far:
# Task 1 Accuracy: 87.78%
# Task 2 Accuracy: 87.45%
# Task 3 Accuracy: 91.73%
#
# ==================================================
# Training on Task 4
# ==================================================
# Task 4, Epoch 1/5, Loss: 0.8390, Accuracy: 82.09%
# Task 4, Epoch 2/5, Loss: 0.6282, Accuracy: 89.41%
# Task 4, Epoch 3/5, Loss: 0.6026, Accuracy: 90.25%
# Task 4, Epoch 4/5, Loss: 0.5907, Accuracy: 90.74%
# Task 4, Epoch 5/5, Loss: 0.5838, Accuracy: 90.94%
#
# Evaluating on all tasks seen so far:
# Task 1 Accuracy: 89.26%
# Task 2 Accuracy: 80.43%
# Task 3 Accuracy: 58.60%
# Task 4 Accuracy: 91.32%
#
# ==================================================
# Training on Task 5
# ==================================================
# Task 5, Epoch 1/5, Loss: 0.8934, Accuracy: 83.06%
# Task 5, Epoch 2/5, Loss: 0.6957, Accuracy: 89.23%
# Task 5, Epoch 3/5, Loss: 0.6694, Accuracy: 90.02%
# Task 5, Epoch 4/5, Loss: 0.6579, Accuracy: 90.28%
# Task 5, Epoch 5/5, Loss: 0.6525, Accuracy: 90.48%
#
# Evaluating on all tasks seen so far:
# Task 1 Accuracy: 88.77%
# Task 2 Accuracy: 85.22%
# Task 3 Accuracy: 53.50%
# Task 4 Accuracy: 44.66%
# Task 5 Accuracy: 91.24%

# %% [markdown]
# ### Metrics & Visualization

# %%
forgetting_rate = calculate_forgetting_metrics(task_accuracies_history, initial_accuracies)
plot_all_results(training_losses, task_accuracies_history, forgetting_rate, num_tasks, method_name='L2 Regularization')
# Out:
# Task Accuracies Table:
#
#               Task 1  Task 2  Task 3  Task 4  Task 5
# After Task 1   91.57     NaN     NaN     NaN     NaN
# After Task 2   89.70   92.06     NaN     NaN     NaN
# After Task 3   87.78   87.45   91.73     NaN     NaN
# After Task 4   89.26   80.43   58.60   91.32     NaN
# After Task 5   88.77   85.22   53.50   44.66   91.24
